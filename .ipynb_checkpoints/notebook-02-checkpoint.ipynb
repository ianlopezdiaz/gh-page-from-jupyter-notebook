# %% [markdown]
# # An example of K-Means++ initialization

# %%
# Authors: The scikit-learn developers
# SPDX-License-Identifier: BSD-3-Clause

import matplotlib.pyplot as plt

from sklearn.cluster import kmeans_plusplus
from sklearn.datasets import make_blobs

# Generate sample data
n_samples = 4000
n_components = 4

X, y_true = make_blobs(
    n_samples=n_samples, centers=n_components, cluster_std=0.60, random_state=0
)
X = X[:, ::-1]

# Calculate seeds from k-means++
centers_init, indices = kmeans_plusplus(X, n_clusters=4, random_state=0)

# Plot init seeds along side sample data
plt.figure(2)
colors = ["#4EACC5", "#FF9C34", "#4E9A06", "m"]

for k, col in enumerate(colors):
    cluster_data = y_true == k
    plt.scatter(X[cluster_data, 0], X[cluster_data, 1], c=col, marker=".", s=10)

plt.scatter(centers_init[:, 0], centers_init[:, 1], c="b", s=50)
plt.title("K-Means++ Initialization")
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 22
#      19 centers_init, indices = kmeans_plusplus(X, n_clusters=4, random_state=0)
#      21 # Plot init seeds along side sample data
# ---> 22 plt.figure(1, 20, 20)
#      23 colors = ["#4EACC5", "#FF9C34", "#4E9A06", "m"]
#      25 for k, col in enumerate(colors):
#
# File ~/anaconda3/envs/data-science/lib/python3.12/site-packages/matplotlib/pyplot.py:1041, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1031 if len(allnums) == max_open_warning >= 1:
#    1032     _api.warn_external(
#    1033         f"More than {max_open_warning} figures have been opened. "
#    1034         f"Figures created through the pyplot interface "
#    (...)   1038         f"Consider using `matplotlib.pyplot.close()`.",
#    1039         RuntimeWarning)
# -> 1041 manager = new_figure_manager(
#    1042     num, figsize=figsize, dpi=dpi,
#    1043     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#    1044     FigureClass=FigureClass, **kwargs)
#    1045 fig = manager.canvas.figure
#    1046 if fig_label:
#
# File ~/anaconda3/envs/data-science/lib/python3.12/site-packages/matplotlib/pyplot.py:551, in new_figure_manager(*args, **kwargs)
#     549 """Create a new figure manager instance."""
#     550 _warn_if_gui_out_of_main_thread()
# --> 551 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File ~/anaconda3/envs/data-science/lib/python3.12/site-packages/matplotlib_inline/backend_inline.py:27, in new_figure_manager(num, FigureClass, *args, **kwargs)
#      21 def new_figure_manager(num, *args, FigureClass=Figure, **kwargs):
#      22     """
#      23     Return a new figure manager for a new figure instance.
#      24
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#
# File ~/anaconda3/envs/data-science/lib/python3.12/site-packages/matplotlib/figure.py:2626, in Figure.__init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2623 if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
#    2624     raise ValueError('figure size must be positive finite not '
#    2625                      f'{figsize}')
# -> 2626 self.bbox_inches = Bbox.from_bounds(0, 0, *figsize)
#    2628 self.dpi_scale_trans = Affine2D().scale(dpi)
#    2629 # do not use property as it will trigger
#
# TypeError: Value after * must be an iterable, not int
